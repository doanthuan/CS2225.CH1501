# %% [markdown]
# Thông tin nhóm: gồm 2 thành viên
#
# > CH1902024	Nguyễn Thanh Tú	N025	tunt.14@grad.uit.edu.vn
#
# > CH1901013	Đoàn Vũ Thuận	N025	thuandv.14@grad.uit.edu.vn
#
# Mô tả đồ án cuối kỳ:
#
#
# https://docs.google.com/document/d/1DEItXGk9Hax6DOvTxagG7XJntzMiLvnoamuuSM3FWRM/edit
